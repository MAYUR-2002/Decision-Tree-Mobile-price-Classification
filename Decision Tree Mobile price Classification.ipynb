# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the data
df_test=pd.read_csv('Mobile Dataset/test.csv')
df_train=pd.read_csv("Mobile Dataset/train.csv")
df_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df_train.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
df_train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# No null values

# %%
# Exploratory Data Analysis

# %%
sns.relplot(df_train['ram'],df_train['battery_power'],hue=df_train['price_range'])
# Out:
# C:\Users\Mayur Pawar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df_train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
corr=df_train.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
# Price range and ram have high correlation

# %%
sns.set(rc={'figure.figsize':(14,14)})
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
df_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df_test.set_index('id')
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# id
# 1              1043     1          1.8         1  14       0           5
# 2               841     1          0.5         1   4       1          61
# 3              1807     1          2.8         0   1       0          27
# 4              1546     0          0.5         1  18       1          25
# 5              1434     0          1.4         0  11       1          49
# ...             ...   ...          ...       ...  ..     ...         ...
# 996            1700     1          1.9         0   0       1          54
# 997             609     0          1.8         1   0       0          13
# 998            1185     0          1.4         0   1       1           8
# 999            1533     1          0.5         1   0       0          50
# 1000           1270     1          0.5         0   4       1          35
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# id
# ...

# %%
df_train.update(df_test)

# %%
df_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0         1043.0   1.0          1.8       1.0  14.0     0.0         5.0
# 1          841.0   1.0          0.5       1.0   4.0     1.0        61.0
# 2         1807.0   1.0          2.8       0.0   1.0     0.0        27.0
# 3         1546.0   0.0          0.5       1.0  18.0     1.0        25.0
# 4         1434.0   0.0          1.4       0.0  11.0     1.0        49.0
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0    0.1      193.0      3.0  ...      226.0    1412.0  3476.0  12.0   7.0
# 1    0.8      191.0      5.0  ...      746.0     857.0  3895.0   6.0   0.0
# 2    0.9      186.0      3.0  ...     1270.0    1366.0  2396.0  17.0  10.0
# 3    0.5       96.0      8.0  ...      295.0    1752.0  3893.0  10.0   0.0
# 4    0.5      108.0      6.0  ...      749.0     810.0  1773.0  15.0   8.0
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df_train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
X=df_train.drop(['price_range'],axis=1)
Y=df_train['price_range']

# %%
#X=df_train[['ram','px_height','px_width','battery_power','sc_w','pc','wifi','int_memory']]
#Y=df_train['price_range']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1600, 20)
# (400, 20)
# (1600,)
# (400,)

# %%
# Decision tree classifier with criterion gini index
'''
from sklearn.tree import DecisionTreeClassifier as DTC
DTC_gini=DTC(criterion='entropy',splitter='best',max_depth=4,min_samples_split=2,min_samples_leaf=2)
# fit the model
DTC_gini.fit(X_train,Y_train)
'''
# Out:
# "\nfrom sklearn.tree import DecisionTreeClassifier as DTC\nDTC_gini=DTC(criterion='entropy',splitter='best',max_depth=4,min_samples_split=2,min_samples_leaf=2)\n# fit the model\nDTC_gini.fit(X_train,Y_train)\n"

# %%
# Decision tree classifier with criterion gini index
"""
from sklearn.tree import DecisionTreeClassifier as DTC
DTC_gini=DTC(criterion='entropy',splitter='random',max_depth=None,min_samples_split=10,max_features='log2')
# fit the model
DTC_gini.fit(X_train,Y_train)
"""
# Out:
# "\nfrom sklearn.tree import DecisionTreeClassifier as DTC\nDTC_gini=DTC(criterion='entropy',splitter='random',max_depth=None,min_samples_split=10,max_features='log2')\n# fit the model\nDTC_gini.fit(X_train,Y_train)\n"

# %%
# Decision tree classifier with criterion gini index
from sklearn.tree import DecisionTreeClassifier as DTC
DTC_entropy=DTC(random_state=0,criterion='entropy',splitter='random')
# fit the model
DTC_entropy.fit(X_train,Y_train,sample_weight=None)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0, splitter='random')

# %%
Y_pred=DTC_entropy.predict(X_test)

# %%
Y_pred
# Out:
# array([0, 3, 1, 1, 1, 1, 3, 1, 1, 1, 3, 1, 2, 0, 3, 0, 3, 3, 1, 3, 3, 0,
#        1, 2, 0, 3, 1, 0, 3, 0, 2, 1, 2, 1, 1, 3, 3, 0, 3, 3, 3, 3, 0, 2,
#        2, 3, 3, 0, 0, 1, 2, 3, 1, 1, 3, 0, 0, 0, 0, 2, 0, 2, 2, 3, 0, 0,
#        0, 3, 3, 2, 2, 1, 0, 1, 3, 0, 0, 0, 1, 1, 2, 1, 2, 2, 1, 3, 1, 0,
#        3, 2, 1, 0, 1, 0, 0, 2, 2, 1, 1, 1, 1, 1, 2, 1, 2, 2, 2, 3, 0, 0,
#        1, 2, 2, 0, 3, 3, 0, 1, 0, 2, 1, 1, 2, 0, 1, 2, 3, 2, 0, 2, 3, 0,
#        2, 3, 1, 0, 1, 2, 1, 1, 3, 2, 0, 1, 0, 2, 2, 1, 2, 0, 2, 1, 0, 0,
#        1, 1, 3, 2, 2, 0, 1, 0, 0, 3, 2, 3, 0, 2, 0, 3, 3, 2, 2, 0, 2, 3,
#        0, 3, 3, 2, 0, 2, 1, 2, 0, 0, 3, 3, 1, 3, 2, 2, 1, 3, 2, 3, 2, 3,
#        2, 2, 0, 3, 2, 0, 0, 0, 0, 2, 0, 3, 0, 1, 2, 1, 0, 1, 0, 3, 0, 0,
#        3, 2, 0, 0, 1, 2, 0, 3, 0, 0, 2, 3, 1, 3, 2, 3, 1, 1, 3, 0, 2, 0,
#        3, 2, 2, 3, 3, 2, 3, 2, 3, 2, 1, 0, 3, 1, 3, 3, 1, 2, 1, 0, 2, 2,
#        2, 1, 1, 3, 2, 3, 1, 2, 1, 0, 0, 0, 2, 3, 2, 0, 3, 0, 3, 3, 1, 3,
# ...

# %%
Y_test.shape
# Out:
# (400,)

# %%
Y_pred.shape
# Out:
# (400,)

# %%
from sklearn.metrics import accuracy_score
print('Model accuracy score using gini index is',accuracy_score(Y_test,Y_pred))
# Out:
# Model accuracy score using gini index is 0.36

# %%
# cheacking train and test set accuracy
y_pred_train=DTC_entropy.predict(X_train)
print("Trainset accuracy score",accuracy_score(Y_train,y_pred_train))
# Out:
# Trainset accuracy score 1.0
